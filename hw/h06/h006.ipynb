# %% [markdown]
# # Homework 06

# %% [markdown]
# ## 1. Import

# %% [markdown]
# ### 1.1 Import packages

# %%
# import standard libraries
import pandas as pd
import numpy as np

# import from scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb

# %% [markdown]
# ### 1.2 Import data

# %%
# variable data
df = pd.read_csv("data/jamb_exam_results.csv", delimiter=',')

# %%
# display the first 5 rows of the data
df.head()
# Out:
#    JAMB_Score  Study_Hours_Per_Week  Attendance_Rate  Teacher_Quality  \
# 0         192                    22               78                4
# 1         207                    14               88                4
# 2         182                    29               87                2
# 3         210                    29               99                2
# 4         199                    12               98                3
#
#    Distance_To_School School_Type School_Location Extra_Tutorials  \
# 0                12.4      Public           Urban             Yes
# 1                 2.7      Public           Rural              No
# 2                 9.6      Public           Rural             Yes
# 3                 2.6      Public           Urban              No
# 4                 8.8      Public           Urban              No
#
#   Access_To_Learning_Materials Parent_Involvement IT_Knowledge  Student_ID  \
# 0                          Yes               High       Medium           1
# 1                          Yes               High         High           2
# 2                          Yes               High       Medium           3
# 3                          Yes             Medium         High           4
# 4                          Yes             Medium       Medium           5
#
#    Age  Gender Socioeconomic_Status Parent_Education_Level  \
# 0   17    Male                  Low               Tertiary
# 1   15    Male                 High                    NaN
# 2   20  Female                 High               Tertiary
# 3   22  Female               Medium               Tertiary
# 4   22  Female               Medium               Tertiary
#
#    Assignments_Completed
# 0                      2
# 1                      1
# 2                      2
# 3                      1
# 4                      1

# %% [markdown]
# ### 1.3 Preparing the dataset

# %%
# Making the column names to be in lower case
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
# removing the column student_id
df = df.drop('student_id', axis=1)

# %%
# filling missing values with 0
df = df.fillna(0)

# %%
# train/validation/test split with 60%/20%/20% distribution.
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# Separate the target variable from the train/val/test sets
y_train = df_train['jamb_score'].values
y_val = df_val['jamb_score'].values
y_test = df_test['jamb_score'].values

del df_train['jamb_score']
del df_val['jamb_score']

# %%
# Use DictVectorizer(sparse=True) to turn the dataframes into matrices.
dv = DictVectorizer(sparse=False)
# convert the dataframes to dictionaries
df_train_dict = df_train.to_dict(orient='records')
# fit the DictVectorizer on the training data
X_train = dv.fit_transform(df_train_dict)
# convert the validation data to dictionaries
df_val_dict = df_val.to_dict(orient='records')
# transform the validation data
X_val = dv.transform(df_val_dict)
# convert test data to dictionaries
df_test_dict = df_test.to_dict(orient='records')
# transform the test data
X_test = dv.transform(df_test_dict)

# %% [markdown]
# ## 2. Questions

# %% [markdown]
# ### 2.1 Question 1

# %%
# Train a DecisionTreeRegressor model
dt_model = DecisionTreeRegressor(max_depth=1)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
# Identify the feature used for splitting the data
feature_names = dv.get_feature_names_out(input_features=df_train.columns)
split_feature_idx = dt_model.tree_.feature[0]
split_feature = feature_names[split_feature_idx]

print(f"Feature used for splitting: {split_feature}")
# Out:
# Feature used for splitting: study_hours_per_week

# %% [markdown]
# ### 2.2 Question 2

# %%
# Create and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=10, random_state=1, n_jobs=-1)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, n_jobs=-1, random_state=1)

# %%
# Make predictions
y_pred = rf_model.predict(X_test)

# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 68.14409732324583

# %% [markdown]
# ### 2.2 Question 3

# %%
# List to store RMSE values for different n_estimators
rmse_values = []

# Loop over different values of n_estimators
for n in range(10, 201, 10):
    # Initialize the model with the current n_estimators and random_state
    rf_model = RandomForestRegressor(n_estimators=n, random_state=1)
    
    # Fit the model on the training data
    rf_model.fit(X_train, y_train)
    
    # Make predictions on the validation data
    y_pred = rf_model.predict(X_val)
    
    # Calculate MSE
    mse = mean_squared_error(y_val, y_pred)
    
    # Calculate RMSE
    rmse = np.sqrt(mse)
    
    # Store the RMSE value
    rmse_values.append((n, rmse))

# Print the RMSE values for different n_estimators
for n, rmse in rmse_values:
    print(f"n_estimators: {n}, RMSE: {rmse}")
# Out:
# n_estimators: 10, RMSE: 42.13724207871227
# n_estimators: 20, RMSE: 41.46121464694444
# n_estimators: 30, RMSE: 41.106170947924596
# n_estimators: 40, RMSE: 40.917193933296545
# n_estimators: 50, RMSE: 40.852278663496854
# n_estimators: 60, RMSE: 40.78428140159447
# n_estimators: 70, RMSE: 40.677098222414024
# n_estimators: 80, RMSE: 40.53933283129176
# n_estimators: 90, RMSE: 40.50434592594835
# n_estimators: 100, RMSE: 40.51680451861919
# n_estimators: 110, RMSE: 40.59335280539747
# n_estimators: 120, RMSE: 40.6248503681005
# n_estimators: 130, RMSE: 40.650840905587195
# n_estimators: 140, RMSE: 40.5948515491302
# n_estimators: 150, RMSE: 40.596715029667116
# n_estimators: 160, RMSE: 40.60350763548252
# n_estimators: 170, RMSE: 40.62754627591216
# n_estimators: 180, RMSE: 40.641313925139386
# n_estimators: 190, RMSE: 40.63135509073867
# n_estimators: 200, RMSE: 40.60101912236933

# %% [markdown]
# ### 2.2 Question 4

# %%
# List to store RMSE values for different combinations of max_depth and n_estimators
results = []

# Loop over different values of max_depth
for max_depth in [10, 15, 20, 25]:
    # List to store RMSE values for different n_estimators for the current max_depth
    rmse_values = []
    
    # Loop over different values of n_estimators
    for n in range(10, 201, 10):
        # Initialize the model with the current max_depth, n_estimators, and random_state
        rf_model = RandomForestRegressor(max_depth=max_depth, n_estimators=n, random_state=1)
        
        # Fit the model on the training data
        rf_model.fit(X_train, y_train)
        
        # Make predictions on the validation data
        y_pred = rf_model.predict(X_val)
        
        # Calculate MSE
        mse = mean_squared_error(y_val, y_pred)
        
        # Calculate RMSE
        rmse = np.sqrt(mse)
        
        # Store the RMSE value
        rmse_values.append(rmse)
    
    # Calculate the mean RMSE for the current max_depth
    mean_rmse = np.mean(rmse_values)
    
    # Store the results
    results.append((max_depth, mean_rmse))

# Print the mean RMSE values for different max_depth
for max_depth, mean_rmse in results:
    print(f"max_depth: {max_depth}, Mean RMSE: {mean_rmse}")
# Out:
# max_depth: 10, Mean RMSE: 40.39249798892396
# max_depth: 15, Mean RMSE: 40.73528172486332
# max_depth: 20, Mean RMSE: 40.739734321829275
# max_depth: 25, Mean RMSE: 40.78786565962805

# %% [markdown]
# ### 2.2 Question 5

# %%
# Initialize the model with the specified parameters
rf_model = RandomForestRegressor(n_estimators=10, max_depth=20, random_state=1, n_jobs=-1)

# Fit the model on the training data
rf_model.fit(X_train, y_train)

# Get the feature importance information
feature_importances = rf_model.feature_importances_
feature_names = df_train.columns

# Combine feature names and their importances
feature_importance_info = list(zip(feature_names, feature_importances))

# Sort the features by their importance
sorted_feature_importance = sorted(feature_importance_info, key=lambda x: x[1], reverse=True)

# Print the sorted feature importances
for feature, importance in sorted_feature_importance:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: school_type, Importance: 0.1497290297846747
# Feature: school_location, Importance: 0.13648580486323686
# Feature: teacher_quality, Importance: 0.06931145469695398
# Feature: distance_to_school, Importance: 0.0315167894546007
# Feature: age, Importance: 0.0177193420394119
# Feature: assignments_completed, Importance: 0.015450360187928142
# Feature: extra_tutorials, Importance: 0.013459336291731936
# Feature: gender, Importance: 0.012404050525957139
# Feature: study_hours_per_week, Importance: 0.012325395818561706
# Feature: it_knowledge, Importance: 0.010382634572648446
# Feature: attendance_rate, Importance: 0.010261891957053597
# Feature: parent_involvement, Importance: 0.009288710588929933
# Feature: socioeconomic_status, Importance: 0.009141479881545294
# Feature: access_to_learning_materials, Importance: 0.009131355726749439
# Feature: parent_education_level, Importance: 0.0

# %% [markdown]
# ### 2.2 Question 6

# %%
# Create DMatrix for train and validation
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

# Create a watchlist
watchlist = [(dtrain, 'train'), (dval, 'eval')]

# Define the parameters
xgb_params = {
    'eta': 0.3, 
    'max_depth': 6,
    'min_child_weight': 1,
    'objective': 'reg:squarederror',
    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

# Train the model with eta=0.3
model_1 = xgb.train(xgb_params, dtrain, num_boost_round=100, evals=watchlist)

# Predict on the validation set
y_pred_1 = model_1.predict(dval)

# Calculate RMSE
rmse_1 = np.sqrt(mean_squared_error(y_val, y_pred_1))
print(f"RMSE with eta=0.3: {rmse_1}")

# Change eta to 0.1
xgb_params['eta'] = 0.1

# Train the model with eta=0.1
model_2 = xgb.train(xgb_params, dtrain, num_boost_round=100, evals=watchlist)

# Predict on the validation set
y_pred_2 = model_2.predict(dval)

# Calculate RMSE
rmse_2 = np.sqrt(mean_squared_error(y_val, y_pred_2))
print(f"RMSE with eta=0.1: {rmse_2}")
# Out:
# [0]	train-rmse:42.69552	eval-rmse:44.86028
# [1]	train-rmse:39.85005	eval-rmse:43.06070
# [2]	train-rmse:37.95285	eval-rmse:41.83772
# [3]	train-rmse:36.52203	eval-rmse:41.26987
# [4]	train-rmse:35.36066	eval-rmse:41.02965
# [5]	train-rmse:34.43646	eval-rmse:40.87186
# [6]	train-rmse:33.71528	eval-rmse:40.69132
# [7]	train-rmse:33.07449	eval-rmse:40.65074
# [8]	train-rmse:32.41772	eval-rmse:40.72710
# [9]	train-rmse:31.91000	eval-rmse:40.82972
# [10]	train-rmse:31.55119	eval-rmse:40.83684
# [11]	train-rmse:30.99534	eval-rmse:40.98243
# [12]	train-rmse:30.33163	eval-rmse:41.05515
# [13]	train-rmse:30.04347	eval-rmse:41.18635
# [14]	train-rmse:29.44279	eval-rmse:41.32160
# [15]	train-rmse:29.08791	eval-rmse:41.37832
# [16]	train-rmse:28.84106	eval-rmse:41.45737
# [17]	train-rmse:28.28883	eval-rmse:41.51113
# [18]	train-rmse:27.90071	eval-rmse:41.55139
# [19]	train-rmse:27.60694	eval-rmse:41.66496
# [20]	train-rmse:27.24424	eval-rmse:41.80313
# [21]	train-rmse:26.79013	eval-rmse:41.88767
# [22]	train-rmse:26.64232	eval-rmse:41.90488
# [23]	train-rmse:26.31972	eval-rmse:41.92316
# [24]	train-rmse:25.88532	eval-rmse:42.08362
# [25]	train-rmse:25.52682	eval-rmse:42.16423
# [26]	train-rmse:25.27021	eval-rmse:42.18007
# [27]	train-rmse:24.83770	eval-rmse:42.25393
# [28]	train-rmse:24.50666	eval-rmse:42.17218
# [29]	train-rmse:24.28500	eval-rmse:42.22800
# [30]	train-rmse:24.12906	eval-rmse:42.28557
# [31]	train-rmse:23.79256	eval-rmse:42.27537
# [32]	train-rmse:23.61943	eval-rmse:42.34086
# [33]	train-rmse:23.21046	eval-rmse:42.35924
# [34]	train-rmse:22.76960	eval-rmse:42.41263
# [35]	train-rmse:22.40407	eval-rmse:42.54946
# [36]	train-rmse:22.21200	eval-rmse:42.53387
# [37]	train-rmse:22.06109	eval-rmse:42.59772
# [38]	train-rmse:21.88417	eval-rmse:42.64574
# [39]	train-rmse:21.72696	eval-rmse:42.66439
# [40]	train-rmse:21.45994	eval-rmse:42.77917
# [41]	train-rmse:21.24770	eval-rmse:42.79287
# [42]	train-rmse:21.09028	eval-rmse:42.79428
# [43]	train-rmse:20.71456	eval-rmse:42.93201
# [44]	train-rmse:20.65221	eval-rmse:42.92877
# [45]	train-rmse:20.39910	eval-rmse:42.92252
# [46]	train-rmse:20.22686	eval-rmse:42.98755
# [47]	train-rmse:20.05491	eval-rmse:42.99944
# [48]	train-rmse:19.85342	eval-rmse:43.04477
# [49]	train-rmse:19.52786	eval-rmse:43.05213
# [50]	train-rmse:19.30407	eval-rmse:43.11630
# [51]	train-rmse:19.19020	eval-rmse:43.14962
# [52]	train-rmse:19.06414	eval-rmse:43.18269
# [53]	train-rmse:18.95703	eval-rmse:43.23604
# [54]	train-rmse:18.64998	eval-rmse:43.32643
# [55]	train-rmse:18.42737	eval-rmse:43.38441
# [56]	train-rmse:18.22228	eval-rmse:43.45045
# [57]	train-rmse:17.86009	eval-rmse:43.45631
# [58]	train-rmse:17.77161	eval-rmse:43.41722
# [59]	train-rmse:17.54300	eval-rmse:43.43040
# [60]	train-rmse:17.42414	eval-rmse:43.40830
# [61]	train-rmse:17.29793	eval-rmse:43.39196
# [62]	train-rmse:16.98232	eval-rmse:43.44147
# [63]	train-rmse:16.70766	eval-rmse:43.49769
# [64]	train-rmse:16.65029	eval-rmse:43.48814
# [65]	train-rmse:16.59974	eval-rmse:43.52522
# [66]	train-rmse:16.49244	eval-rmse:43.56568
# [67]	train-rmse:16.20230	eval-rmse:43.64686
# [68]	train-rmse:16.03162	eval-rmse:43.68218
# [69]	train-rmse:15.80482	eval-rmse:43.74895
# [70]	train-rmse:15.74173	eval-rmse:43.77894
# [71]	train-rmse:15.46582	eval-rmse:43.86327
# [72]	train-rmse:15.32512	eval-rmse:43.88453
# [73]	train-rmse:15.25418	eval-rmse:43.87270
# [74]	train-rmse:15.13885	eval-rmse:43.92972
# [75]	train-rmse:14.87321	eval-rmse:43.91229
# [76]	train-rmse:14.74268	eval-rmse:43.96224
# [77]	train-rmse:14.55016	eval-rmse:44.02037
# [78]	train-rmse:14.45302	eval-rmse:44.03039
# [79]	train-rmse:14.31586	eval-rmse:44.08974
# [80]	train-rmse:14.28350	eval-rmse:44.08528
# [81]	train-rmse:14.16512	eval-rmse:44.07639
# [82]	train-rmse:13.94135	eval-rmse:44.11316
# [83]	train-rmse:13.78280	eval-rmse:44.15607
# [84]	train-rmse:13.72782	eval-rmse:44.16948
# [85]	train-rmse:13.64009	eval-rmse:44.22602
# [86]	train-rmse:13.55103	eval-rmse:44.22414
# [87]	train-rmse:13.45733	eval-rmse:44.22955
# [88]	train-rmse:13.27029	eval-rmse:44.20077
# [89]	train-rmse:13.06611	eval-rmse:44.25658
# [90]	train-rmse:12.90222	eval-rmse:44.30365
# [91]	train-rmse:12.70138	eval-rmse:44.27992
# [92]	train-rmse:12.52598	eval-rmse:44.27966
# [93]	train-rmse:12.35376	eval-rmse:44.30546
# [94]	train-rmse:12.23012	eval-rmse:44.33776
# [95]	train-rmse:12.05464	eval-rmse:44.31210
# [96]	train-rmse:11.83129	eval-rmse:44.35656
# [97]	train-rmse:11.69930	eval-rmse:44.40721
# [98]	train-rmse:11.59889	eval-rmse:44.42582
# [99]	train-rmse:11.56417	eval-rmse:44.43210
# RMSE with eta=0.3: 44.432098039002526
# [0]	train-rmse:45.50072	eval-rmse:46.99373
# [1]	train-rmse:44.12583	eval-rmse:45.89771
# [2]	train-rmse:42.92815	eval-rmse:45.01746
# [3]	train-rmse:41.90445	eval-rmse:44.27569
# [4]	train-rmse:40.94238	eval-rmse:43.62411
# [5]	train-rmse:40.15460	eval-rmse:43.05644
# [6]	train-rmse:39.43451	eval-rmse:42.64605
# [7]	train-rmse:38.77902	eval-rmse:42.28889
# [8]	train-rmse:38.17103	eval-rmse:42.00035
# [9]	train-rmse:37.60436	eval-rmse:41.73633
# [10]	train-rmse:37.11353	eval-rmse:41.55631
# [11]	train-rmse:36.65501	eval-rmse:41.33670
# [12]	train-rmse:36.26337	eval-rmse:41.18307
# [13]	train-rmse:35.84634	eval-rmse:41.03057
# [14]	train-rmse:35.45796	eval-rmse:40.89024
# [15]	train-rmse:35.07766	eval-rmse:40.70892
# [16]	train-rmse:34.73181	eval-rmse:40.60601
# [17]	train-rmse:34.40922	eval-rmse:40.47982
# [18]	train-rmse:34.13466	eval-rmse:40.43780
# [19]	train-rmse:33.88018	eval-rmse:40.38390
# [20]	train-rmse:33.57997	eval-rmse:40.37859
# [21]	train-rmse:33.33993	eval-rmse:40.33974
# [22]	train-rmse:33.08144	eval-rmse:40.31700
# [23]	train-rmse:32.90907	eval-rmse:40.27079
# [24]	train-rmse:32.67941	eval-rmse:40.24539
# [25]	train-rmse:32.50134	eval-rmse:40.21661
# [26]	train-rmse:32.34352	eval-rmse:40.18931
# [27]	train-rmse:32.10382	eval-rmse:40.16582
# [28]	train-rmse:31.87260	eval-rmse:40.17918
# [29]	train-rmse:31.63118	eval-rmse:40.19048
# [30]	train-rmse:31.47315	eval-rmse:40.20963
# [31]	train-rmse:31.33204	eval-rmse:40.19347
# [32]	train-rmse:31.14061	eval-rmse:40.18380
# [33]	train-rmse:31.00229	eval-rmse:40.20241
# [34]	train-rmse:30.87401	eval-rmse:40.19533
# [35]	train-rmse:30.68870	eval-rmse:40.19360
# [36]	train-rmse:30.51937	eval-rmse:40.16657
# [37]	train-rmse:30.39206	eval-rmse:40.17015
# [38]	train-rmse:30.15893	eval-rmse:40.11076
# [39]	train-rmse:30.06269	eval-rmse:40.12398
# [40]	train-rmse:29.89807	eval-rmse:40.15747
# [41]	train-rmse:29.77216	eval-rmse:40.16214
# [42]	train-rmse:29.68555	eval-rmse:40.18541
# [43]	train-rmse:29.60613	eval-rmse:40.19638
# [44]	train-rmse:29.44768	eval-rmse:40.21938
# [45]	train-rmse:29.33094	eval-rmse:40.21096
# [46]	train-rmse:29.17393	eval-rmse:40.25150
# [47]	train-rmse:29.07139	eval-rmse:40.27005
# [48]	train-rmse:28.90613	eval-rmse:40.27137
# [49]	train-rmse:28.68387	eval-rmse:40.25459
# [50]	train-rmse:28.58793	eval-rmse:40.28533
# [51]	train-rmse:28.43762	eval-rmse:40.32253
# [52]	train-rmse:28.30836	eval-rmse:40.33475
# [53]	train-rmse:28.20341	eval-rmse:40.36778
# [54]	train-rmse:28.04428	eval-rmse:40.42419
# [55]	train-rmse:27.95277	eval-rmse:40.44296
# [56]	train-rmse:27.79120	eval-rmse:40.46342
# [57]	train-rmse:27.63979	eval-rmse:40.47682
# [58]	train-rmse:27.51074	eval-rmse:40.50269
# [59]	train-rmse:27.38582	eval-rmse:40.55488
# [60]	train-rmse:27.26360	eval-rmse:40.55054
# [61]	train-rmse:27.11823	eval-rmse:40.55428
# [62]	train-rmse:26.93721	eval-rmse:40.59138
# [63]	train-rmse:26.80458	eval-rmse:40.63833
# [64]	train-rmse:26.72133	eval-rmse:40.67049
# [65]	train-rmse:26.56706	eval-rmse:40.66625
# [66]	train-rmse:26.50977	eval-rmse:40.68481
# [67]	train-rmse:26.48079	eval-rmse:40.67549
# [68]	train-rmse:26.35456	eval-rmse:40.66876
# [69]	train-rmse:26.19720	eval-rmse:40.71233
# [70]	train-rmse:26.05959	eval-rmse:40.73555
# [71]	train-rmse:25.98355	eval-rmse:40.73001
# [72]	train-rmse:25.85978	eval-rmse:40.76108
# [73]	train-rmse:25.78199	eval-rmse:40.75415
# [74]	train-rmse:25.61175	eval-rmse:40.76484
# [75]	train-rmse:25.55747	eval-rmse:40.76267
# [76]	train-rmse:25.45273	eval-rmse:40.80265
# [77]	train-rmse:25.37953	eval-rmse:40.80691
# [78]	train-rmse:25.34547	eval-rmse:40.81149
# [79]	train-rmse:25.30869	eval-rmse:40.81515
# [80]	train-rmse:25.13835	eval-rmse:40.82813
# [81]	train-rmse:25.08265	eval-rmse:40.82773
# [82]	train-rmse:24.98067	eval-rmse:40.87072
# [83]	train-rmse:24.83828	eval-rmse:40.86600
# [84]	train-rmse:24.76938	eval-rmse:40.85858
# [85]	train-rmse:24.64140	eval-rmse:40.87915
# [86]	train-rmse:24.48190	eval-rmse:40.92002
# [87]	train-rmse:24.33811	eval-rmse:40.91237
# [88]	train-rmse:24.19041	eval-rmse:40.93271
# [89]	train-rmse:24.04297	eval-rmse:40.92325
# [90]	train-rmse:23.93958	eval-rmse:40.89645
# [91]	train-rmse:23.80207	eval-rmse:40.94051
# [92]	train-rmse:23.69255	eval-rmse:40.93450
# [93]	train-rmse:23.59784	eval-rmse:40.94918
# [94]	train-rmse:23.50978	eval-rmse:40.95805
# [95]	train-rmse:23.39469	eval-rmse:40.95651
# [96]	train-rmse:23.28229	eval-rmse:40.97949
# [97]	train-rmse:23.24969	eval-rmse:40.99391
# [98]	train-rmse:23.17460	eval-rmse:41.01797
# [99]	train-rmse:23.14487	eval-rmse:41.04335
# RMSE with eta=0.1: 41.043354592351655
